# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df=pd.read_excel("/Users/eneskoser/Doctor Stats/data/tez veri 23Agustos 2024.xlsx",sheet_name="veri").drop(columns="Unnamed: 0")

# %%
df.head()
# Out:
#        Örnek Cinsiyet  Cins kod      Ad Soyad  \
# 0   17111367    Bayan       2.0  FUNDA AKBABA
# 1   17425221    Bayan       2.0     NURAN ÇAL
# 2   16343086    Bayan       2.0   GÖZDE ERGEN
# 3  171358777    Erkek       1.0   UĞUR YAZGAN
# 4   16173365    Bayan       2.0  ABİR HANNURA
#
#                                                  Pol pol kod  Sonuç  B12 kod  \
# 0                  BÖBREK NAKLİ HAZIRLIK POLİKLİNİĞİ      15  >1515        6
# 1               SARIYER ÇOCUK NÖROLOJİ İHSAN KAFADAR       4  >1515        6
# 2  SARIYER ÇOCUK METABOLİZMA HAST. TANYEL ZÜBARİOĞLU       6  >1500        6
# 3             ÇOCUK SAĞLIĞI POLİKLİNİĞİ SEYRANTEPE-1       1   1826        6
# 4                ÇOCUK POL. ENİSE AVCI DURMUŞALİOĞLU       1    284        4
#
#         Eski Sonuc1       Eski Sonuc2          Kayit Tar. Dogum Tar.  \
# 0  >1500 (02.10.19)  >1500 (01.07.19) 2019-12-10 10:15:00 2004-11-05
# 1  >1500 (19.02.18)  >1500 (31.01.18) 2020-02-24 09:04:00 2010-06-17
# ...
